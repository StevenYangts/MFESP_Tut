# %% [markdown]
# # Agenda:
#
#
#
# 1. Basic Python Data Structure for Finance:
#     - List
#     - Dictionary
#
#
# 2. Data management:
#
#
# - Dataframe operations
#     - parsing time series data, boolean mask, data filtering, merging, and slicing
# - Dealing with time series with Pandas
#
#
# 3. Finance-related applcations:
#     - Monte Carlo Simulation
#     - Option pricing: BSM

# %% [markdown]
# # Data Structure

# %% [markdown]
# ### List

# %%
# Store multiple ordered, and changeable items in a single variable

# Creating a list
Ticker = ["TD","BMO","BNS"]
Ticker
# Out:
# ['TD', 'BMO', 'BNS']

# %%
# Assessing elements in a list
Ticker[0]
# Out:
# 'TD'

# %%
# List length
len(Ticker)
# Out:
# 3

# %%
# Modifying elements

# changing elements by index
Ticker[0] = 'RY'
Ticker
# Out:
# ['RY', 'BMO', 'BNS']

# %%
# Adding elements
Ticker.append('TD')
Ticker
# Out:
# ['RY', 'BMO', 'BNS', 'TD']

# %%
# Removing elements

# Method 1: remove specific item
Ticker.remove("RY")
Ticker
# Out:
# ['BMO', 'BNS', 'TD']

# %%
# Method 2: remove elements by index
Ticker.pop(0)
Ticker
# Out:
# ['BNS', 'TD']

# %%
# List slicing 
numbers = [1,2,3,4,5]

# index-based slicing-- this will return list with values [2,3,4]
# Starting from the 2nd item (python index starts with 0) and select up to the 4th element 
numbers[1:4]
# Out:
# [2, 3, 4]

# %% [markdown]
# ##### List comprehension
# A concise way of creating lists in Python using iteration which follows the below format:
#
#
# ***new_list = [expression for item in iterable]***
#
#
# **"expression"**: This is the expression or operation you want to perform on each item in the iterable.
#
# **"item"**: This is a variable that represents each element in the iterable.
#
# **"iterable"**: This is the collection of items you want to iterate over (e.g., a list, string, or range).

# %%
# A simple illustration
numbers = [1, 2, 3, 4, 5]
# The ** operation would not work on list object
# numbers_sqre = numbers**2

# %%
squared_numbers = [x ** 2 for x in numbers]
squared_numbers
# Out:
# [1, 4, 9, 16, 25]

# %%
# Or you can also extract values based on certain conditions

numbers = [1, 2, 3, 4, 5]
even_numbers = [x for x in numbers if x % 2 == 0]
odd_numbers = [x for x in numbers if x not in even_numbers]

# %%
even_numbers
# Out:
# [2, 4]

# %%
odd_numbers
# Out:
# [1, 3, 5]

# %% [markdown]
# ### Dictionaries

# %%
# Dictionary is a collection of key-value pairs

# Creating a dictionary using {}
stocks ={'RY':'bank',
        'BMO':'bank',
        'MSFT':'Tech'}

keys = stocks.keys()
values = stocks.values()
items = stocks.items()

stocks['RY']
# Out:
# 'bank'

# %%
print(keys)
print(values)
print(items)
# Out:
# dict_keys(['RY', 'BMO', 'MSFT'])
# dict_values(['bank', 'bank', 'Tech'])
# dict_items([('RY', 'bank'), ('BMO', 'bank'), ('MSFT', 'Tech')])

# %%
# Ways to loop through a dict
for key, value in stocks.items():
    print(key, ":", value)
# Out:
# RY : bank
# BMO : bank
# MSFT : Tech

# %%
for key in stocks.keys():
    print(key)
# Out:
# RY
# BMO
# MSFT

# %%
for value in stocks.values():
    print(value)
# Out:
# bank
# bank
# Tech

# %%
len(stocks)
# Out:
# 3

# %%
# Remove an item
del stocks['MSFT']
stocks
# Out:
# {'RY': 'bank', 'BMO': 'bank'}

# %% [markdown]
# # Data management using Pandas

# %%
### Prelimin

# %%
# from pandas import *
import pandas as pd

# %%
# Convert dict into a df
students = {
    "Name": ["John", "Jane", "David"],
    "Age": [20, 19, 22],
    "Grade": ["A", "B", "A"]
}

df = pd.DataFrame(students)
df
# Out:
#     Name  Age Grade
# 0   John   20     A
# 1   Jane   19     B
# 2  David   22     A

# %%
Ticker_info =pd.DataFrame(["RY","BMO","BNS","MSFT"],columns=["Ticker"])
Ticker_info
# Out:
#   Ticker
# 0     RY
# 1    BMO
# 2    BNS
# 3   MSFT

# %%
Ticker_info["Industry"]=("Bank","Bank","Bank","Tech")
Ticker_info
# Out:
#   Ticker Industry
# 0     RY     Bank
# 1    BMO     Bank
# 2    BNS     Bank
# 3   MSFT     Tech

# %%
### Load the data

# %%
# Use read_excel fct to import data frome excel and parse it into a df object
Data = pd.read_excel("FTS_data_MFESP.xlsx")
Data
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2018-05-29   75.220001   75.290001   74.019997   74.430000   61.714794
# 1    2018-05-30   75.059998   75.379997   74.610001   75.230003   62.378124
# 2    2018-05-31   75.010002   75.639999   74.330002   75.589996   62.676613
# 3    2018-06-01   76.080002   76.230003   75.110001   75.709999   62.776123
# 4    2018-06-04   75.959999   76.839996   75.959999   76.489998   63.422871
# ...         ...         ...         ...         ...         ...         ...
# 5027 2023-05-19  316.739990  318.750000  316.369995  318.339996  318.339996
# 5028 2023-05-22  318.600006  322.589996  318.010010  321.179993  321.179993
# 5029 2023-05-23  320.029999  322.720001  315.250000  315.260010  315.260010
# 5030 2023-05-24  314.730011  316.500000  312.609985  313.850006  313.850006
# 5031 2023-05-25  323.239990  326.899994  320.000000  325.920013  325.920013
#
#         Volume Ticker
# 0      1230700     RY
# 1       978000     RY
# 2      1157400     RY
# 3       667300     RY
# 4       682900     RY
# ...        ...    ...
# 5027  27529500   MSFT
# 5028  24115700   MSFT
# 5029  30797200   MSFT
# 5030  23384900   MSFT
# 5031  43301700   MSFT
#
# [5032 rows x 8 columns]

# %%
# Returns the first 5 rows of the df 
Data.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close   Volume  \
# 0 2018-05-29  75.220001  75.290001  74.019997  74.430000  61.714794  1230700
# 1 2018-05-30  75.059998  75.379997  74.610001  75.230003  62.378124   978000
# 2 2018-05-31  75.010002  75.639999  74.330002  75.589996  62.676613  1157400
# 3 2018-06-01  76.080002  76.230003  75.110001  75.709999  62.776123   667300
# 4 2018-06-04  75.959999  76.839996  75.959999  76.489998  63.422871   682900
#
#   Ticker
# 0     RY
# 1     RY
# 2     RY
# 3     RY
# 4     RY

# %%
# Returns the last 5 rows of the df 
Data.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 5027 2023-05-19  316.739990  318.750000  316.369995  318.339996  318.339996
# 5028 2023-05-22  318.600006  322.589996  318.010010  321.179993  321.179993
# 5029 2023-05-23  320.029999  322.720001  315.250000  315.260010  315.260010
# 5030 2023-05-24  314.730011  316.500000  312.609985  313.850006  313.850006
# 5031 2023-05-25  323.239990  326.899994  320.000000  325.920013  325.920013
#
#         Volume Ticker
# 5027  27529500   MSFT
# 5028  24115700   MSFT
# 5029  30797200   MSFT
# 5030  23384900   MSFT
# 5031  43301700   MSFT

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5032 entries, 0 to 5031
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5032 non-null   datetime64[ns]
#  1   Open       5032 non-null   float64
#  2   High       5032 non-null   float64
#  3   Low        5032 non-null   float64
#  4   Close      5032 non-null   float64
#  5   Adj Close  5032 non-null   float64
#  6   Volume     5032 non-null   int64
#  7   Ticker     5032 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(1)
# memory usage: 314.6+ KB

# %%
Data.columns.tolist()
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Ticker']

# %%
Data['Ticker'].drop_duplicates().tolist()
# Out:
# ['RY', 'BNS', 'BMO', 'MSFT']

# %%
# Selection based on index

# Set the index to date
Data_wd=Data.set_index(['Date'])
Data_wd
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-29   75.220001   75.290001   74.019997   74.430000   61.714794
# 2018-05-30   75.059998   75.379997   74.610001   75.230003   62.378124
# 2018-05-31   75.010002   75.639999   74.330002   75.589996   62.676613
# 2018-06-01   76.080002   76.230003   75.110001   75.709999   62.776123
# 2018-06-04   75.959999   76.839996   75.959999   76.489998   63.422871
# ...                ...         ...         ...         ...         ...
# 2023-05-19  316.739990  318.750000  316.369995  318.339996  318.339996
# 2023-05-22  318.600006  322.589996  318.010010  321.179993  321.179993
# 2023-05-23  320.029999  322.720001  315.250000  315.260010  315.260010
# 2023-05-24  314.730011  316.500000  312.609985  313.850006  313.850006
# 2023-05-25  323.239990  326.899994  320.000000  325.920013  325.920013
#
#               Volume Ticker
# Date
# 2018-05-29   1230700     RY
# 2018-05-30    978000     RY
# 2018-05-31   1157400     RY
# 2018-06-01    667300     RY
# 2018-06-04    682900     RY
# ...              ...    ...
# 2023-05-19  27529500   MSFT
# 2023-05-22  24115700   MSFT
# 2023-05-23  30797200   MSFT
# 2023-05-24  23384900   MSFT
# 2023-05-25  43301700   MSFT
#
# [5032 rows x 7 columns]

# %%
# label-based selection using loc
filtered_data_1 = Data_wd.loc[['2019-10-03']]

# %%
filtered_data_1
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-10-03   78.870003   78.940002   77.970001   78.820000   67.918121
# 2019-10-03   55.400002   55.400002   54.820000   55.360001   45.724640
# 2019-10-03   71.489998   71.940002   70.940002   71.589996   60.903847
# 2019-10-03  134.949997  136.750000  133.220001  136.279999  131.422562
#
#               Volume Ticker
# Date
# 2019-10-03   1417900     RY
# 2019-10-03    783500    BNS
# 2019-10-03    838800    BMO
# 2019-10-03  24132900   MSFT

# %%
# integer position based screening
# single bracket returns a series object
Data_wd.iloc[0]
# Out:
# Open           75.22
# High           75.29
# Low            74.02
# Close          74.43
# Adj Close    61.7148
# Volume       1230700
# Ticker            RY
# Name: 2018-05-29 00:00:00, dtype: object

# %%
# [[]] returns a df object
Data_wd.iloc[[0]]
# Out:
#                  Open       High        Low  Close  Adj Close   Volume Ticker
# Date
# 2018-05-29  75.220001  75.290001  74.019997  74.43  61.714794  1230700     RY

# %%
# Selection by range
Data_wd.iloc[0:100]
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2018-05-29  75.220001  75.290001  74.019997  74.430000  61.714794  1230700
# 2018-05-30  75.059998  75.379997  74.610001  75.230003  62.378124   978000
# 2018-05-31  75.010002  75.639999  74.330002  75.589996  62.676613  1157400
# 2018-06-01  76.080002  76.230003  75.110001  75.709999  62.776123   667300
# 2018-06-04  75.959999  76.839996  75.959999  76.489998  63.422871   682900
# ...               ...        ...        ...        ...        ...      ...
# 2018-10-11  76.650002  76.809998  75.660004  75.769997  63.408672  1378700
# 2018-10-12  76.879997  76.919998  75.400002  75.779999  63.417065   826900
# 2018-10-15  76.029999  76.389999  75.339996  75.760002  63.400318   534700
# 2018-10-16  76.250000  76.940002  76.089996  76.879997  64.337608   853500
# 2018-10-17  76.849998  76.949997  76.360001  76.830002  64.295776   588600
#
#            Ticker
# Date
# 2018-05-29     RY
# 2018-05-30     RY
# 2018-05-31     RY
# 2018-06-01     RY
# 2018-06-04     RY
# ...           ...
# 2018-10-11     RY
# 2018-10-12     RY
# 2018-10-15     RY
# 2018-10-16     RY
# 2018-10-17     RY
#
# [100 rows x 7 columns]

# %%
# Selecting every other row
Data_wd.iloc[0:10:2]
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2018-05-29  75.220001  75.290001  74.019997  74.430000  61.714794  1230700
# 2018-05-31  75.010002  75.639999  74.330002  75.589996  62.676613  1157400
# 2018-06-04  75.959999  76.839996  75.959999  76.489998  63.422871   682900
# 2018-06-06  77.150002  77.180000  76.510002  76.610001  63.522373   573800
# 2018-06-08  76.400002  77.220001  76.290001  77.190002  64.003288   637200
#
#            Ticker
# Date
# 2018-05-29     RY
# 2018-05-31     RY
# 2018-06-04     RY
# 2018-06-06     RY
# 2018-06-08     RY

# %%
# Select only Close column
# Note that iloc only accepts integer input, so using column name will not work
Data_wd.iloc[:100,[3]]
# Out:
#                 Close
# Date
# 2018-05-29  74.430000
# 2018-05-30  75.230003
# 2018-05-31  75.589996
# 2018-06-01  75.709999
# 2018-06-04  76.489998
# ...               ...
# 2018-10-11  75.769997
# 2018-10-12  75.779999
# 2018-10-15  75.760002
# 2018-10-16  76.879997
# 2018-10-17  76.830002
#
# [100 rows x 1 columns]

# %%
# Dataframe slicing using boolean mask with 1 condition
RY = Data_wd[Data_wd['Ticker']=='RY']
RY
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2018-05-29  75.220001  75.290001  74.019997  74.430000  61.714794  1230700
# 2018-05-30  75.059998  75.379997  74.610001  75.230003  62.378124   978000
# 2018-05-31  75.010002  75.639999  74.330002  75.589996  62.676613  1157400
# 2018-06-01  76.080002  76.230003  75.110001  75.709999  62.776123   667300
# 2018-06-04  75.959999  76.839996  75.959999  76.489998  63.422871   682900
# ...               ...        ...        ...        ...        ...      ...
# 2023-05-19  95.110001  95.220001  93.820000  94.199997  94.199997   740200
# 2023-05-22  94.419998  94.419998  93.370003  94.160004  94.160004   525500
# 2023-05-23  94.010002  94.220001  93.250000  93.339996  93.339996   717200
# 2023-05-24  92.309998  92.629997  90.910004  91.099998  91.099998  1010900
# 2023-05-25  89.959999  90.879997  88.029999  89.099998  89.099998  1924500
#
#            Ticker
# Date
# 2018-05-29     RY
# 2018-05-30     RY
# 2018-05-31     RY
# 2018-06-01     RY
# 2018-06-04     RY
# ...           ...
# 2023-05-19     RY
# 2023-05-22     RY
# 2023-05-23     RY
# 2023-05-24     RY
# 2023-05-25     RY
#
# [1258 rows x 7 columns]

# %%
# slicing with multiple conditions

RY_ch = Data_wd[(Data_wd['Ticker']=='RY') &
                (Data_wd['Close'] >=116)]
RY_ch
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-13  116.760002  117.300003  116.110001  116.260002  109.764992
# 2022-01-14  115.599998  117.339996  115.360001  117.330002  110.775223
# 2022-01-18  118.279999  119.410004  117.779999  118.790001  112.153656
# 2022-01-19  118.910004  119.169998  116.650002  117.480003  110.916832
# 2022-01-20  117.570000  118.370003  115.940002  116.099998  109.613922
# 2022-02-08  115.180000  116.250000  115.029999  116.029999  110.473320
#
#              Volume Ticker
# Date
# 2022-01-13   975100     RY
# 2022-01-14  1656100     RY
# 2022-01-18  2531900     RY
# 2022-01-19  2799600     RY
# 2022-01-20  2074500     RY
# 2022-02-08  1555600     RY

# %%
### Merging DFs

# %%
# Ticker_info df we created earlier
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html
Ticker_info
# Out:
#   Ticker Industry
# 0     RY     Bank
# 1    BMO     Bank
# 2    BNS     Bank
# 3   MSFT     Tech

# %%
Data_ind =Data_wd.merge(Ticker_info,on='Ticker',how="left")
Data_ind
# Out:
#             Open        High         Low       Close   Adj Close    Volume  \
# 0      75.220001   75.290001   74.019997   74.430000   61.714794   1230700
# 1      75.059998   75.379997   74.610001   75.230003   62.378124    978000
# 2      75.010002   75.639999   74.330002   75.589996   62.676613   1157400
# 3      76.080002   76.230003   75.110001   75.709999   62.776123    667300
# 4      75.959999   76.839996   75.959999   76.489998   63.422871    682900
# ...          ...         ...         ...         ...         ...       ...
# 5027  316.739990  318.750000  316.369995  318.339996  318.339996  27529500
# 5028  318.600006  322.589996  318.010010  321.179993  321.179993  24115700
# 5029  320.029999  322.720001  315.250000  315.260010  315.260010  30797200
# 5030  314.730011  316.500000  312.609985  313.850006  313.850006  23384900
# 5031  323.239990  326.899994  320.000000  325.920013  325.920013  43301700
#
#      Ticker Industry
# 0        RY     Bank
# 1        RY     Bank
# 2        RY     Bank
# 3        RY     Bank
# 4        RY     Bank
# ...     ...      ...
# 5027   MSFT     Tech
# 5028   MSFT     Tech
# 5029   MSFT     Tech
# 5030   MSFT     Tech
# 5031   MSFT     Tech
#
# [5032 rows x 8 columns]

# %%
# Generating descriptive stats

# %%
Data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  5032.000000  5032.000000  5032.000000  5032.000000  5032.000000
# mean    108.566951   109.527540   107.565312   108.583706   102.095030
# std      69.766968    70.568061    68.943299    69.807227    71.251720
# min      34.220001    34.990002    31.940001    32.160000    26.891064
# 25%      63.407500    63.864999    62.830002    63.432499    57.549372
# 50%      81.400002    81.715000    80.979999    81.360001    70.715210
# 75%     109.754999   110.875002   108.792502   109.742498   104.036993
# max     344.619995   349.670013   342.200012   343.109985   338.335907
#
#              Volume
# count  5.032000e+03
# mean   8.277335e+06
# std    1.419412e+07
# min    8.300000e+04
# 25%    6.261750e+05
# 50%    1.006700e+06
# 75%    7.702350e+06
# max    1.112421e+08

# %%
# Summary stats by columns
RY['Close'].mean(), RY['Close'].std()
# Out:
# (86.74863271224162, 13.79973899309931)

# %%
# Incorporating boolean mask
Data[Data['Ticker']=='BNS']['Close'].median()
# Out:
# 55.290001

# %%
# Incorporating groupyby() function
Data.groupby('Ticker').std()['Close']
# Out:
# Ticker
# BMO     17.625640
# BNS      8.404439
# MSFT    71.337597
# RY      13.799739
# Name: Close, dtype: float64

# %%
# dealing with missing values

Data.fillna(method="bfill") # back fill missing data from the previous row
Data.fillna(method="ffill") #forward fill missing data from the next row
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2018-05-29   75.220001   75.290001   74.019997   74.430000   61.714794
# 1    2018-05-30   75.059998   75.379997   74.610001   75.230003   62.378124
# 2    2018-05-31   75.010002   75.639999   74.330002   75.589996   62.676613
# 3    2018-06-01   76.080002   76.230003   75.110001   75.709999   62.776123
# 4    2018-06-04   75.959999   76.839996   75.959999   76.489998   63.422871
# ...         ...         ...         ...         ...         ...         ...
# 5027 2023-05-19  316.739990  318.750000  316.369995  318.339996  318.339996
# 5028 2023-05-22  318.600006  322.589996  318.010010  321.179993  321.179993
# 5029 2023-05-23  320.029999  322.720001  315.250000  315.260010  315.260010
# 5030 2023-05-24  314.730011  316.500000  312.609985  313.850006  313.850006
# 5031 2023-05-25  323.239990  326.899994  320.000000  325.920013  325.920013
#
#         Volume Ticker
# 0      1230700     RY
# 1       978000     RY
# 2      1157400     RY
# 3       667300     RY
# 4       682900     RY
# ...        ...    ...
# 5027  27529500   MSFT
# 5028  24115700   MSFT
# 5029  30797200   MSFT
# 5030  23384900   MSFT
# 5031  43301700   MSFT
#
# [5032 rows x 8 columns]

# %%
# Applying functions on data
Data_ind['HL_Ratio'] = Data_ind['High']/Data_ind['Low']
Data_ind
# Out:
#             Open        High         Low       Close   Adj Close    Volume  \
# 0      75.220001   75.290001   74.019997   74.430000   61.714794   1230700
# 1      75.059998   75.379997   74.610001   75.230003   62.378124    978000
# 2      75.010002   75.639999   74.330002   75.589996   62.676613   1157400
# 3      76.080002   76.230003   75.110001   75.709999   62.776123    667300
# 4      75.959999   76.839996   75.959999   76.489998   63.422871    682900
# ...          ...         ...         ...         ...         ...       ...
# 5027  316.739990  318.750000  316.369995  318.339996  318.339996  27529500
# 5028  318.600006  322.589996  318.010010  321.179993  321.179993  24115700
# 5029  320.029999  322.720001  315.250000  315.260010  315.260010  30797200
# 5030  314.730011  316.500000  312.609985  313.850006  313.850006  23384900
# 5031  323.239990  326.899994  320.000000  325.920013  325.920013  43301700
#
#      Ticker Industry  HL_Ratio
# 0        RY     Bank  1.017158
# 1        RY     Bank  1.010320
# 2        RY     Bank  1.017624
# 3        RY     Bank  1.014911
# 4        RY     Bank  1.011585
# ...     ...      ...       ...
# 5027   MSFT     Tech  1.007523
# 5028   MSFT     Tech  1.014402
# 5029   MSFT     Tech  1.023695
# 5030   MSFT     Tech  1.012444
# 5031   MSFT     Tech  1.021562
#
# [5032 rows x 9 columns]

# %%
# Converting HL_Ratio into net-return like format, we can choose to apply log using np.log
import numpy as np
Data_ind['log_HL']=Data_ind['HL_Ratio'].map(np.log)
Data_ind
# Out:
#             Open        High         Low       Close   Adj Close    Volume  \
# 0      75.220001   75.290001   74.019997   74.430000   61.714794   1230700
# 1      75.059998   75.379997   74.610001   75.230003   62.378124    978000
# 2      75.010002   75.639999   74.330002   75.589996   62.676613   1157400
# 3      76.080002   76.230003   75.110001   75.709999   62.776123    667300
# 4      75.959999   76.839996   75.959999   76.489998   63.422871    682900
# ...          ...         ...         ...         ...         ...       ...
# 5027  316.739990  318.750000  316.369995  318.339996  318.339996  27529500
# 5028  318.600006  322.589996  318.010010  321.179993  321.179993  24115700
# 5029  320.029999  322.720001  315.250000  315.260010  315.260010  30797200
# 5030  314.730011  316.500000  312.609985  313.850006  313.850006  23384900
# 5031  323.239990  326.899994  320.000000  325.920013  325.920013  43301700
#
#      Ticker Industry  HL_Ratio    log_HL
# 0        RY     Bank  1.017158  0.017012
# 1        RY     Bank  1.010320  0.010267
# 2        RY     Bank  1.017624  0.017471
# 3        RY     Bank  1.014911  0.014801
# 4        RY     Bank  1.011585  0.011518
# ...     ...      ...       ...       ...
# 5027   MSFT     Tech  1.007523  0.007495
# 5028   MSFT     Tech  1.014402  0.014299
# 5029   MSFT     Tech  1.023695  0.023419
# 5030   MSFT     Tech  1.012444  0.012367
# 5031   MSFT     Tech  1.021562  0.021333
#
# [5032 rows x 10 columns]

# %%
# Applying lambda fct 1 
Data_ind['Red'] = Data_ind['HL_Ratio'].apply(lambda x: x<1.02)

# %%
Data_ind
# Out:
#             Open        High         Low       Close   Adj Close    Volume  \
# 0      75.220001   75.290001   74.019997   74.430000   61.714794   1230700
# 1      75.059998   75.379997   74.610001   75.230003   62.378124    978000
# 2      75.010002   75.639999   74.330002   75.589996   62.676613   1157400
# 3      76.080002   76.230003   75.110001   75.709999   62.776123    667300
# 4      75.959999   76.839996   75.959999   76.489998   63.422871    682900
# ...          ...         ...         ...         ...         ...       ...
# 5027  316.739990  318.750000  316.369995  318.339996  318.339996  27529500
# 5028  318.600006  322.589996  318.010010  321.179993  321.179993  24115700
# 5029  320.029999  322.720001  315.250000  315.260010  315.260010  30797200
# 5030  314.730011  316.500000  312.609985  313.850006  313.850006  23384900
# 5031  323.239990  326.899994  320.000000  325.920013  325.920013  43301700
#
#      Ticker Industry  HL_Ratio    log_HL    Red
# 0        RY     Bank  1.017158  0.017012   True
# 1        RY     Bank  1.010320  0.010267   True
# 2        RY     Bank  1.017624  0.017471   True
# 3        RY     Bank  1.014911  0.014801   True
# 4        RY     Bank  1.011585  0.011518   True
# ...     ...      ...       ...       ...    ...
# 5027   MSFT     Tech  1.007523  0.007495   True
# 5028   MSFT     Tech  1.014402  0.014299   True
# 5029   MSFT     Tech  1.023695  0.023419  False
# 5030   MSFT     Tech  1.012444  0.012367   True
# 5031   MSFT     Tech  1.021562  0.021333  False
#
# [5032 rows x 11 columns]

# %%
# Applying lambda fct 2 
# Close to close ret
Data_ind['Ret']=Data_ind.groupby("Ticker")["Close"].apply(lambda x: x.pct_change(1))
Data_ind
# Out:
#             Open        High         Low       Close   Adj Close    Volume  \
# 0      75.220001   75.290001   74.019997   74.430000   61.714794   1230700
# 1      75.059998   75.379997   74.610001   75.230003   62.378124    978000
# 2      75.010002   75.639999   74.330002   75.589996   62.676613   1157400
# 3      76.080002   76.230003   75.110001   75.709999   62.776123    667300
# 4      75.959999   76.839996   75.959999   76.489998   63.422871    682900
# ...          ...         ...         ...         ...         ...       ...
# 5027  316.739990  318.750000  316.369995  318.339996  318.339996  27529500
# 5028  318.600006  322.589996  318.010010  321.179993  321.179993  24115700
# 5029  320.029999  322.720001  315.250000  315.260010  315.260010  30797200
# 5030  314.730011  316.500000  312.609985  313.850006  313.850006  23384900
# 5031  323.239990  326.899994  320.000000  325.920013  325.920013  43301700
#
#      Ticker Industry  HL_Ratio    log_HL    Red       Ret
# 0        RY     Bank  1.017158  0.017012   True       NaN
# 1        RY     Bank  1.010320  0.010267   True  0.010748
# 2        RY     Bank  1.017624  0.017471   True  0.004785
# 3        RY     Bank  1.014911  0.014801   True  0.001588
# 4        RY     Bank  1.011585  0.011518   True  0.010302
# ...     ...      ...       ...       ...    ...       ...
# 5027   MSFT     Tech  1.007523  0.007495   True -0.000565
# 5028   MSFT     Tech  1.014402  0.014299   True  0.008921
# 5029   MSFT     Tech  1.023695  0.023419  False -0.018432
# 5030   MSFT     Tech  1.012444  0.012367   True -0.004473
# 5031   MSFT     Tech  1.021562  0.021333  False  0.038458
#
# [5032 rows x 12 columns]

# %%
MSFT_result = Data_ind[Data_ind['Ticker']=='MSFT']

# %%
MSFT_result
# Out:
#             Open        High         Low       Close   Adj Close    Volume  \
# 3774   97.839996   98.879997   97.230003   98.010002   92.697647  28671000
# 3775   98.309998   99.250000   97.910004   98.949997   93.586685  22158500
# 3776   99.290001   99.989998   98.610001   98.839996   93.482635  34140900
# 3777   99.279999  100.860001   99.169998  100.790001   95.326965  28655600
# 3778  101.260002  101.860001  100.849998  101.669998   96.159271  27281600
# ...          ...         ...         ...         ...         ...       ...
# 5027  316.739990  318.750000  316.369995  318.339996  318.339996  27529500
# 5028  318.600006  322.589996  318.010010  321.179993  321.179993  24115700
# 5029  320.029999  322.720001  315.250000  315.260010  315.260010  30797200
# 5030  314.730011  316.500000  312.609985  313.850006  313.850006  23384900
# 5031  323.239990  326.899994  320.000000  325.920013  325.920013  43301700
#
#      Ticker Industry  HL_Ratio    log_HL    Red       Ret
# 3774   MSFT     Tech  1.016970  0.016828   True       NaN
# 3775   MSFT     Tech  1.013686  0.013593   True  0.009591
# 3776   MSFT     Tech  1.013994  0.013897   True -0.001112
# 3777   MSFT     Tech  1.017041  0.016898   True  0.019729
# 3778   MSFT     Tech  1.010015  0.009965   True  0.008731
# ...     ...      ...       ...       ...    ...       ...
# 5027   MSFT     Tech  1.007523  0.007495   True -0.000565
# 5028   MSFT     Tech  1.014402  0.014299   True  0.008921
# 5029   MSFT     Tech  1.023695  0.023419  False -0.018432
# 5030   MSFT     Tech  1.012444  0.012367   True -0.004473
# 5031   MSFT     Tech  1.021562  0.021333  False  0.038458
#
# [1258 rows x 12 columns]

# %% [markdown]
# ### Dates in pandas
# Data objects in pandas have the Timestamp type. Conversion:
#
# 1. From `datetime` to `Timestamp`: **Timestamp(d)**
# 2. From `Timestamp` to `datetime`: **ts.to_datetime()**
#
# Data objects in numpy have the datetime64 type. Conversion:
#
# 1. From `datetime` to `datetime64`: **np.datetime64(datetime)**
# 2. From `datetime64` to `datetime`: **datetime64.astype(dt.datetime)**
#
# The `datetime.datetime.strptime` function allows to convert a string with a general format into a datetime object. The format must be translated with the following placeholders:
# 1. `%Y` for year
# 2. `%m` for month
# 3. `%d` for day
# 4. `%H` for hour
# 5. `%M` for minute
# 6. `%S` for second
# 7. `%f` for microseconds
#
#
# Note: Plotting support with datetime64 is limited in matplotlib

# %%
Data['Date_str'] =Data['Date'].map(str)

# %%
Data
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2018-05-29   75.220001   75.290001   74.019997   74.430000   61.714794
# 1    2018-05-30   75.059998   75.379997   74.610001   75.230003   62.378124
# 2    2018-05-31   75.010002   75.639999   74.330002   75.589996   62.676613
# 3    2018-06-01   76.080002   76.230003   75.110001   75.709999   62.776123
# 4    2018-06-04   75.959999   76.839996   75.959999   76.489998   63.422871
# ...         ...         ...         ...         ...         ...         ...
# 5027 2023-05-19  316.739990  318.750000  316.369995  318.339996  318.339996
# 5028 2023-05-22  318.600006  322.589996  318.010010  321.179993  321.179993
# 5029 2023-05-23  320.029999  322.720001  315.250000  315.260010  315.260010
# 5030 2023-05-24  314.730011  316.500000  312.609985  313.850006  313.850006
# 5031 2023-05-25  323.239990  326.899994  320.000000  325.920013  325.920013
#
#         Volume Ticker             Date_str
# 0      1230700     RY  2018-05-29 00:00:00
# 1       978000     RY  2018-05-30 00:00:00
# 2      1157400     RY  2018-05-31 00:00:00
# 3       667300     RY  2018-06-01 00:00:00
# 4       682900     RY  2018-06-04 00:00:00
# ...        ...    ...                  ...
# 5027  27529500   MSFT  2023-05-19 00:00:00
# 5028  24115700   MSFT  2023-05-22 00:00:00
# 5029  30797200   MSFT  2023-05-23 00:00:00
# 5030  23384900   MSFT  2023-05-24 00:00:00
# 5031  43301700   MSFT  2023-05-25 00:00:00
#
# [5032 rows x 9 columns]

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5032 entries, 0 to 5031
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5032 non-null   datetime64[ns]
#  1   Open       5032 non-null   float64
#  2   High       5032 non-null   float64
#  3   Low        5032 non-null   float64
#  4   Close      5032 non-null   float64
#  5   Adj Close  5032 non-null   float64
#  6   Volume     5032 non-null   int64
#  7   Ticker     5032 non-null   object
#  8   Date_str   5032 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(2)
# memory usage: 353.9+ KB

# %%
from datetime import datetime

def convert_date(date_string, format_string):
    date_object = datetime.strptime(date_string, format_string)
    return date_object

# %%
# 2023-05-25 00:00:00
format_string = "%Y-%m-%d %H:%M:%S"

# %%
# Using apply fct to apply our defined convert_date fct to each row of the Date_str column
Data['proper_date'] = Data['Date_str'].apply(convert_date,format_string = format_string)

# %%
Data['proper_date'][0]
# Out:
# Timestamp('2018-05-29 00:00:00')

# %%
# Time delta combining with lambda function
# Create a time Offest column
import datetime as dt

Data['time_Offset'] = 2

# %%
Data
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2018-05-29   75.220001   75.290001   74.019997   74.430000   61.714794
# 1    2018-05-30   75.059998   75.379997   74.610001   75.230003   62.378124
# 2    2018-05-31   75.010002   75.639999   74.330002   75.589996   62.676613
# 3    2018-06-01   76.080002   76.230003   75.110001   75.709999   62.776123
# 4    2018-06-04   75.959999   76.839996   75.959999   76.489998   63.422871
# ...         ...         ...         ...         ...         ...         ...
# 5027 2023-05-19  316.739990  318.750000  316.369995  318.339996  318.339996
# 5028 2023-05-22  318.600006  322.589996  318.010010  321.179993  321.179993
# 5029 2023-05-23  320.029999  322.720001  315.250000  315.260010  315.260010
# 5030 2023-05-24  314.730011  316.500000  312.609985  313.850006  313.850006
# 5031 2023-05-25  323.239990  326.899994  320.000000  325.920013  325.920013
#
#         Volume Ticker             Date_str proper_date  time_Offset
# 0      1230700     RY  2018-05-29 00:00:00  2018-05-29            2
# 1       978000     RY  2018-05-30 00:00:00  2018-05-30            2
# 2      1157400     RY  2018-05-31 00:00:00  2018-05-31            2
# 3       667300     RY  2018-06-01 00:00:00  2018-06-01            2
# 4       682900     RY  2018-06-04 00:00:00  2018-06-04            2
# ...        ...    ...                  ...         ...          ...
# 5027  27529500   MSFT  2023-05-19 00:00:00  2023-05-19            2
# 5028  24115700   MSFT  2023-05-22 00:00:00  2023-05-22            2
# 5029  30797200   MSFT  2023-05-23 00:00:00  2023-05-23            2
# 5030  23384900   MSFT  2023-05-24 00:00:00  2023-05-24            2
# 5031  43301700   MSFT  2023-05-25 00:00:00  2023-05-25            2
#
# [5032 rows x 11 columns]

# %%
# Since 'proper_date' column is already in datetime dtype (datetime), we convert numeric values from time_offset
# into a timedelta, which allows you to perform basic operations for datetime object.
Data['Date_adj'] = Data['proper_date'] + Data['time_Offset'].apply(lambda x: dt.timedelta(hours=x))
Data
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2018-05-29   75.220001   75.290001   74.019997   74.430000   61.714794
# 1    2018-05-30   75.059998   75.379997   74.610001   75.230003   62.378124
# 2    2018-05-31   75.010002   75.639999   74.330002   75.589996   62.676613
# 3    2018-06-01   76.080002   76.230003   75.110001   75.709999   62.776123
# 4    2018-06-04   75.959999   76.839996   75.959999   76.489998   63.422871
# ...         ...         ...         ...         ...         ...         ...
# 5027 2023-05-19  316.739990  318.750000  316.369995  318.339996  318.339996
# 5028 2023-05-22  318.600006  322.589996  318.010010  321.179993  321.179993
# 5029 2023-05-23  320.029999  322.720001  315.250000  315.260010  315.260010
# 5030 2023-05-24  314.730011  316.500000  312.609985  313.850006  313.850006
# 5031 2023-05-25  323.239990  326.899994  320.000000  325.920013  325.920013
#
#         Volume Ticker             Date_str proper_date  time_Offset  \
# 0      1230700     RY  2018-05-29 00:00:00  2018-05-29            2
# 1       978000     RY  2018-05-30 00:00:00  2018-05-30            2
# 2      1157400     RY  2018-05-31 00:00:00  2018-05-31            2
# 3       667300     RY  2018-06-01 00:00:00  2018-06-01            2
# 4       682900     RY  2018-06-04 00:00:00  2018-06-04            2
# ...        ...    ...                  ...         ...          ...
# 5027  27529500   MSFT  2023-05-19 00:00:00  2023-05-19            2
# 5028  24115700   MSFT  2023-05-22 00:00:00  2023-05-22            2
# 5029  30797200   MSFT  2023-05-23 00:00:00  2023-05-23            2
# 5030  23384900   MSFT  2023-05-24 00:00:00  2023-05-24            2
# 5031  43301700   MSFT  2023-05-25 00:00:00  2023-05-25            2
#
#                 Date_adj
# 0    2018-05-29 02:00:00
# 1    2018-05-30 02:00:00
# 2    2018-05-31 02:00:00
# 3    2018-06-01 02:00:00
# 4    2018-06-04 02:00:00
# ...                  ...
# 5027 2023-05-19 02:00:00
# 5028 2023-05-22 02:00:00
# 5029 2023-05-23 02:00:00
# 5030 2023-05-24 02:00:00
# 5031 2023-05-25 02:00:00
#
# [5032 rows x 12 columns]

# %% [markdown]
# # Finance Applications

# %% [markdown]
# ### Monte Carlo Simulation and BS Prices

# %%
# Simulation - BS Stock prices
import numpy as np
import numpy.random as npr
from matplotlib import pyplot as plt

# %% [markdown]
# Let the stock price $S_t$ follow a geometric brownian motion with drift $r$ and volatility $\sigma$,
#
# \begin{equation}
# dS_t=r S_t \times dt+ \sigma S_t \times dz_t
# \end{equation}
#
#
#
# The stock price at time $T$, $S_T$, is:
#
# \begin{equation}
# S_T=S_0\times exp\left(\left(r-\frac{1}{2}\sigma^2\right)T+\sigma\sqrt{T} z\right),
# \end{equation}

# %%
# Simulate 10,000 random stock prices in 2 years with spot price S0 =30, rf= 7%, annualized vol = 20%

S0=30 # initial stock price
r=0.07 # expected return
sigma=0.2 # volatility
T=2 # time 
I=10**4 # number of simulations

ST1=S0*np.exp((r-0.5*sigma**2)*T+sigma*np.sqrt(T)*npr.randn(I))

# drift component = (r-0.5*sigma**2)*T
# random component = sigma*np.sqrt(T)*npr.randn(I))


plt.figure(figsize=(10,4))
plt.hist(ST1, bins=50)
plt.xlabel("Stock price", fontsize=18);

# %% [markdown]
# ### Monte Carlo Simulation and BS Stock price paths

# %%
# Simulation - BS Stock price paths
# Expect for now, we want the entire path of stock prices as opposed to the end values.

# %% [markdown]
# In discrete time, from $t-\Delta t$ to $t$, we have a similar expression:
#
# \begin{equation}
# S_t=S_{t-\Delta t}\exp\left(\left(r-\frac{1}{2}\sigma^2\right)\Delta t+\sigma\sqrt{\Delta t} z\right),
# \end{equation}

# %%
I=10**5 # number of simulations
M=50 # number of steps; assuming 25 steps each year, 2 years give 50 steps
dt=T/M # step size
S=np.zeros((M+1,I)) # initialize an array to store simulated prices
step_sig = sigma *np.sqrt(1/(M/))
S[0]=S0 # Price path starts with spot price S0
for t in range(1,M+1):
    # Note that BSM assumes geometric Brownian motion, which contains a constant (drift)
    # Therefore the stock price path is NOT stationary 
    # Stock price in each period is going to be dependent on price from the previous step
    S[t]=S[t-1]*np.exp((r-0.5*sigma**2)*dt+sigma*np.sqrt(dt)*npr.randn(I))

    
plt.figure(figsize=(10,4))
plt.plot(S[:,0],ls='--', c='r')
plt.plot(S[:,I-1],c='b')
plt.xlabel("Time", fontsize=18)
plt.ylabel("Price", fontsize=18)
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ### BS Option Price

# %% [markdown]
# The Black-Scholes formula for pricing a call option:
#
# $$ c = S_t \times N(d_1) - K e^{-rT} N(d_2) $$
#
# where $d_1=\frac{\log\frac{S_t}{K}+\left(r+\frac{\sigma^2}{2}\right)T}{\sigma \sqrt{T}}$
#
# and $d_2=d_1-\sigma\sqrt{T}$.

# %%
from scipy.stats import norm

def BlackScholes(T,S,K,sigma,r,typeCP):
    d1=(np.log(S/K)+(r+0.5*sigma**2)*T)/(sigma*np.sqrt(T))
    d2=d1-sigma*np.sqrt(T)
  
    call=S*norm.cdf(d1)-K*np.exp(-r*T)*norm.cdf(d2)
    put = K*np.exp(-r*T)*norm.cdf(-d2)- S*norm.cdf(-d1)
  
    if typeCP=='call':
        return call
    else:
        return put

# %%
BlackScholes(T=2,S=30,K=30,sigma=0.2,r=0.07,typeCP='put')
# Out:
# 1.5691999835242374
